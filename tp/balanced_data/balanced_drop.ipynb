# %%
import pandas as pd
import numpy as np
import optuna
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score, classification_report, f1_score
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Carga

# %%
# ---------------------------------------------------------
# 1. Load the Datasets
# ---------------------------------------------------------
print("Loading datasets...")

DATA_PATH = '../processed_datasets/'
X_TRAIN_PATH = DATA_PATH + 'X_train_catboost.parquet'
X_VAL_PATH = DATA_PATH + 'X_val_catboost.parquet'
X_TEST_PATH = DATA_PATH + 'X_test_catboost.parquet'

Y_TRAIN_PATH = DATA_PATH + 'y_train.csv'
Y_VAL_PATH = DATA_PATH + 'y_val.csv'
Y_TEST_PATH = DATA_PATH + 'y_test.csv'
# Using fastparquet to avoid any ArrowKeyError version conflicts

features_to_drop = ['WFO', 'SOURCE']

# Load the data and drop the columns in one go
X_train = pd.read_parquet(X_TRAIN_PATH, engine="fastparquet").drop(columns=features_to_drop)
X_val = pd.read_parquet(X_VAL_PATH, engine="fastparquet").drop(columns=features_to_drop)
X_test = pd.read_parquet(X_TEST_PATH, engine="fastparquet").drop(columns=features_to_drop)

y_train = pd.read_csv(Y_TRAIN_PATH).squeeze()
y_val = pd.read_csv(Y_VAL_PATH).squeeze()
y_test = pd.read_csv(Y_TEST_PATH).squeeze()

#Class balance by dropping
min_class_size = y_train.value_counts().min()
train_data = X_train.copy()
train_data['target_label'] = y_train
balanced_train_data = train_data.groupby('target_label').sample(n=min_class_size, random_state=42)
balanced_train_data = balanced_train_data.sample(frac=1.0, random_state=42).reset_index(drop=True)
y_train = balanced_train_data['target_label']
X_train = balanced_train_data.drop(columns=['target_label'])

print(f"Train shapes: X={X_train.shape}, y={y_train.shape}")
print(f"Validation shapes: X={X_val.shape}, y={y_val.shape}")
print(f"Test shapes: X={X_test.shape}, y={y_test.shape}\n")

categorical_features = X_train.select_dtypes(include=['object', 'category', 'string']).columns.tolist()
#Added day of week since its encoded but not ordinal
categorical_features.extend(['DAY_OF_WEEK'])
print(f"Detected {len(categorical_features)} categorical features: {categorical_features}")
# Out:
# Loading datasets...
# Train shapes: X=(94115, 30), y=(94115,)
# Validation shapes: X=(156915, 30), y=(156915,)
# Test shapes: X=(115998, 30), y=(115998,)
#
# Detected 9 categorical features: ['EVENT_TYPE', 'CZ_TYPE', 'STATE', 'REGION', 'SEASON', 'TIME_OF_DAY', 'MAGNITUDE_TYPE', 'FLOOD_CAUSE', 'DAY_OF_WEEK']

# %%
#Check if balancing worked
sns.countplot(x=y_train)
plt.title('y_train')
plt.xlabel('Label')
plt.ylabel('Samples')
plt.show()

# %% [markdown]
# ### Optuna

# %%
# ---------------------------------------------------------
# 2. Define the Optuna Objective Function
# ---------------------------------------------------------
static_params = {
    "random_seed": 42,
    "verbose": False,
    "task_type": "GPU",
    "eval_metric": "TotalF1:average=Macro"
}

def objective(trial):
    # Define the hyperparameter search space
    params = {
        "iterations": trial.suggest_int("iterations", 500, 2000),
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.1, log=True),
        "depth": trial.suggest_int("depth", 4, 10),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1, 10),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 1, 50),
    }
    params.update(static_params)
    # Instantiate the model for this trial
    model = CatBoostClassifier(**params)

    # Fit the model using the Validation set for early stopping
    model.fit(
        X_train, 
        y_train,
        cat_features=categorical_features,
        eval_set=[(X_val, y_val)],
        early_stopping_rounds=100, 
        use_best_model=True
    )

    # Predict discrete classes, not probabilities
    preds_class = model.predict(X_val)
    preds_class = np.squeeze(preds_class) # Ensure flat 1D array
    
    # Calculate Macro F1
    macro_f1 = f1_score(y_val, preds_class, average='macro')
    
    return macro_f1

# %%
# ---------------------------------------------------------
# 3. Run the Optuna Study
# ---------------------------------------------------------
print("Starting Optuna hyperparameter tuning...")

# Suppress Optuna's verbose trial-by-trial logs if desired
# optuna.logging.set_verbosity(optuna.logging.WARNING)

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=30) # Adjust n_trials based on your time constraints

print("\n--- Optimization Finished ---")
print(f"Best Validation Logloss: {study.best_value:.4f}")
print("Best Parameters:")
for key, value in study.best_params.items():
    print(f"  {key}: {value}")
# Out:
# [I 2026-06-12 10:47:44,495] A new study created in memory with name: no-name-4d974323-f4ba-4694-b432-a72bc5b988ee
# Starting Optuna hyperparameter tuning...
# [I 2026-06-12 10:47:51,610] Trial 0 finished with value: 0.39634902794401694 and parameters: {'iterations': 627, 'learning_rate': 0.014812508348851438, 'depth': 4, 'l2_leaf_reg': 3.539283598590564, 'min_data_in_leaf': 7}. Best is trial 0 with value: 0.39634902794401694.
# [I 2026-06-12 10:48:09,079] Trial 1 finished with value: 0.4426251971442987 and parameters: {'iterations': 1654, 'learning_rate': 0.06719904247426893, 'depth': 8, 'l2_leaf_reg': 1.5972436313618799, 'min_data_in_leaf': 6}. Best is trial 1 with value: 0.4426251971442987.
# [I 2026-06-12 10:48:50,692] Trial 2 finished with value: 0.44455786496687083 and parameters: {'iterations': 1471, 'learning_rate': 0.06082795329167581, 'depth': 9, 'l2_leaf_reg': 7.22349832633326, 'min_data_in_leaf': 32}. Best is trial 2 with value: 0.44455786496687083.
# [I 2026-06-12 10:49:23,485] Trial 3 finished with value: 0.44112759808006025 and parameters: {'iterations': 1903, 'learning_rate': 0.04171723605678562, 'depth': 7, 'l2_leaf_reg': 8.780647555270429, 'min_data_in_leaf': 10}. Best is trial 2 with value: 0.44455786496687083.
# [I 2026-06-12 10:49:29,706] Trial 4 finished with value: 0.3666241444347462 and parameters: {'iterations': 1263, 'learning_rate': 0.0020113556044613805, 'depth': 6, 'l2_leaf_reg': 7.977130071696057, 'min_data_in_leaf': 31}. Best is trial 2 with value: 0.44455786496687083.
# [I 2026-06-12 10:49:48,545] Trial 5 finished with value: 0.4349917232710639 and parameters: {'iterations': 772, 'learning_rate': 0.04643739471770381, 'depth': 8, 'l2_leaf_reg': 6.087976565638004, 'min_data_in_leaf': 10}. Best is trial 2 with value: 0.44455786496687083.
# [I 2026-06-12 10:50:04,611] Trial 6 finished with value: 0.4416047822091252 and parameters: {'iterations': 1434, 'learning_rate': 0.09486098178017802, 'depth': 5, 'l2_leaf_reg': 2.550074480658937, 'min_data_in_leaf': 11}. Best is trial 2 with value: 0.44455786496687083.
# [I 2026-06-12 10:50:10,509] Trial 7 finished with value: 0.4233244620246315 and parameters: {'iterations': 555, 'learning_rate': 0.08447125689698134, 'depth': 4, 'l2_leaf_reg': 1.8061037100611665, 'min_data_in_leaf': 6}. Best is trial 2 with value: 0.44455786496687083.
# [I 2026-06-12 10:50:15,322] Trial 8 finished with value: 0.3517989731166442 and parameters: {'iterations': 1051, 'learning_rate': 0.0035884972264727663, 'depth': 5, 'l2_leaf_reg': 6.8571980383665, 'min_data_in_leaf': 24}. Best is trial 2 with value: 0.44455786496687083.
# [I 2026-06-12 10:50:28,823] Trial 9 finished with value: 0.358467937491434 and parameters: {'iterations': 1943, 'learning_rate': 0.0010704509124398608, 'depth': 7, 'l2_leaf_reg': 3.628294042516118, 'min_data_in_leaf': 50}. Best is trial 2 with value: 0.44455786496687083.
# [I 2026-06-12 10:51:23,554] Trial 10 finished with value: 0.4218356182122399 and parameters: {'iterations': 1016, 'learning_rate': 0.013605572035159675, 'depth': 10, 'l2_leaf_reg': 9.742976274085354, 'min_data_in_leaf': 39}. Best is trial 2 with value: 0.44455786496687083.
# [I 2026-06-12 10:52:20,110] Trial 11 finished with value: 0.43897280089251645 and parameters: {'iterations': 1601, 'learning_rate': 0.02691985340993931, 'depth': 9, 'l2_leaf_reg': 4.825004026337349, 'min_data_in_leaf': 22}. Best is trial 2 with value: 0.44455786496687083.
# [I 2026-06-12 10:53:19,756] Trial 12 finished with value: 0.4430558317909169 and parameters: {'iterations': 1641, 'learning_rate': 0.028134962989636574, 'depth': 9, 'l2_leaf_reg': 1.1719704644564182, 'min_data_in_leaf': 34}. Best is trial 2 with value: 0.44455786496687083.
# [I 2026-06-12 10:54:44,587] Trial 13 finished with value: 0.4225309220750245 and parameters: {'iterations': 1702, 'learning_rate': 0.006956948668412938, 'depth': 10, 'l2_leaf_reg': 7.010658340285367, 'min_data_in_leaf': 36}. Best is trial 2 with value: 0.44455786496687083.
# [I 2026-06-12 10:55:20,397] Trial 14 finished with value: 0.4381523629928165 and parameters: {'iterations': 1419, 'learning_rate': 0.03164028603036987, 'depth': 9, 'l2_leaf_reg': 4.7267796721001805, 'min_data_in_leaf': 45}. Best is trial 2 with value: 0.44455786496687083.
# [I 2026-06-12 10:56:02,044] Trial 15 finished with value: 0.4378835599737861 and parameters: {'iterations': 1421, 'learning_rate': 0.02325838849511837, 'depth': 9, 'l2_leaf_reg': 5.61906669913141, 'min_data_in_leaf': 19}. Best is trial 2 with value: 0.44455786496687083.
# [I 2026-06-12 10:56:36,927] Trial 16 finished with value: 0.42366990362160595 and parameters: {'iterations': 1783, 'learning_rate': 0.007167247673805866, 'depth': 8, 'l2_leaf_reg': 1.0136816276073175, 'min_data_in_leaf': 29}. Best is trial 2 with value: 0.44455786496687083.
# [I 2026-06-12 10:57:30,879] Trial 17 finished with value: 0.4332123250962888 and parameters: {'iterations': 1161, 'learning_rate': 0.020077272810934226, 'depth': 10, 'l2_leaf_reg': 7.905919263331419, 'min_data_in_leaf': 37}. Best is trial 2 with value: 0.44455786496687083.
# [I 2026-06-12 10:58:03,708] Trial 18 finished with value: 0.4414873240711484 and parameters: {'iterations': 1501, 'learning_rate': 0.05243627521819482, 'depth': 9, 'l2_leaf_reg': 3.415112572924114, 'min_data_in_leaf': 17}. Best is trial 2 with value: 0.44455786496687083.
# [I 2026-06-12 10:58:28,949] Trial 19 finished with value: 0.4199286045834688 and parameters: {'iterations': 1283, 'learning_rate': 0.009449136611777858, 'depth': 8, 'l2_leaf_reg': 4.7326299172569275, 'min_data_in_leaf': 31}. Best is trial 2 with value: 0.44455786496687083.
# [I 2026-06-12 10:58:48,425] Trial 20 finished with value: 0.43767479630504963 and parameters: {'iterations': 1818, 'learning_rate': 0.0379333605332683, 'depth': 6, 'l2_leaf_reg': 9.787701972729973, 'min_data_in_leaf': 43}. Best is trial 2 with value: 0.44455786496687083.
# [I 2026-06-12 10:59:01,163] Trial 21 finished with value: 0.440258430961472 and parameters: {'iterations': 1602, 'learning_rate': 0.06637545643521921, 'depth': 8, 'l2_leaf_reg': 1.207072764339682, 'min_data_in_leaf': 1}. Best is trial 2 with value: 0.44455786496687083.
# [I 2026-06-12 10:59:29,580] Trial 22 finished with value: 0.44218468827330815 and parameters: {'iterations': 1643, 'learning_rate': 0.06307036409791016, 'depth': 9, 'l2_leaf_reg': 2.25314876016726, 'min_data_in_leaf': 27}. Best is trial 2 with value: 0.44455786496687083.
# [I 2026-06-12 10:59:43,951] Trial 23 finished with value: 0.4449361334998345 and parameters: {'iterations': 2000, 'learning_rate': 0.06559600785940017, 'depth': 8, 'l2_leaf_reg': 2.813570506638582, 'min_data_in_leaf': 33}. Best is trial 23 with value: 0.4449361334998345.
# [I 2026-06-12 11:01:16,089] Trial 24 finished with value: 0.4376363594862898 and parameters: {'iterations': 1997, 'learning_rate': 0.017743328916918336, 'depth': 10, 'l2_leaf_reg': 6.680445039787617, 'min_data_in_leaf': 34}. Best is trial 23 with value: 0.4449361334998345.
# [I 2026-06-12 11:01:26,221] Trial 25 finished with value: 0.4431395424563614 and parameters: {'iterations': 1797, 'learning_rate': 0.09697380098738533, 'depth': 7, 'l2_leaf_reg': 2.8802631526301976, 'min_data_in_leaf': 41}. Best is trial 23 with value: 0.4449361334998345.
# [I 2026-06-12 11:01:40,815] Trial 26 finished with value: 0.4473050176726299 and parameters: {'iterations': 1812, 'learning_rate': 0.09940185824542776, 'depth': 7, 'l2_leaf_reg': 2.9482986032866387, 'min_data_in_leaf': 41}. Best is trial 26 with value: 0.4473050176726299.
# [I 2026-06-12 11:01:54,435] Trial 27 finished with value: 0.44091367802817494 and parameters: {'iterations': 1841, 'learning_rate': 0.05573641772263318, 'depth': 6, 'l2_leaf_reg': 4.192406197350459, 'min_data_in_leaf': 48}. Best is trial 26 with value: 0.4473050176726299.
# [I 2026-06-12 11:02:09,809] Trial 28 finished with value: 0.4417445784916543 and parameters: {'iterations': 1978, 'learning_rate': 0.0753400914007014, 'depth': 7, 'l2_leaf_reg': 5.485703194877764, 'min_data_in_leaf': 44}. Best is trial 26 with value: 0.4473050176726299.
# [I 2026-06-12 11:02:35,977] Trial 29 finished with value: 0.4445714030256795 and parameters: {'iterations': 1744, 'learning_rate': 0.03814058113025721, 'depth': 8, 'l2_leaf_reg': 3.3502061344897194, 'min_data_in_leaf': 40}. Best is trial 26 with value: 0.4473050176726299.
# --- Optimization Finished ---
# Best Validation Logloss: 0.4473
# Best Parameters:
#   iterations: 1812
#   learning_rate: 0.09940185824542776
#   depth: 7
#   l2_leaf_reg: 2.9482986032866387
#   min_data_in_leaf: 41

# %% [markdown]
# ### Entrenamiento

# %%
# ---------------------------------------------------------
# 4. Train Final Model & Evaluate on Test Set
# ---------------------------------------------------------
print("\nTraining final model with best parameters...")

# Initialize the final model

final_params = study.best_params.copy()
final_params.update(static_params)
final_model = CatBoostClassifier(**final_params)

# Retrain using Train set and use Validation set for early stopping one last time
final_model.fit(
    X_train, 
    y_train,
    cat_features=categorical_features,
    eval_set=[(X_val, y_val)],
    early_stopping_rounds=100,
    use_best_model=True
)
# Out:
# Training final model with best parameters...
# CatBoostClassifier(depth=7, eval_metric='TotalF1:average=Macro', iterations=1812, l2_leaf_reg=2.9482986032866387, learning_rate=0.09940185824542776, min_data_in_leaf=41, random_seed=42, task_type='GPU', verbose=False)

# %% [markdown]
# ### Prediccion en Test

# %%
# Make final predictions on the completely unseen X_test
y_pred = final_model.predict(X_test)

# Print performance metrics
test_accuracy = accuracy_score(y_test, y_pred)
print(f"Final Test Accuracy: {test_accuracy:.4f}\n")

print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Final Test Accuracy: 0.7558
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.82      0.88     86950
#            1       0.56      0.71      0.62     17859
#            2       0.23      0.29      0.26      7736
#            3       0.18      0.31      0.22      2274
#            4       0.17      0.44      0.24      1179
#
#     accuracy                           0.76    115998
#    macro avg       0.41      0.51      0.44    115998
# weighted avg       0.81      0.76      0.78    115998

# %%
final_model.save_model("catboost_balanced_drop.cbm")

# %% [markdown]
# ### Feature Importance

# %%
model = CatBoostClassifier().load_model("catboost_balanced_drop.cbm")

# %%
importances = model.get_feature_importance()
feature_names = model.feature_names_

# Pack them into a DataFrame for clean sorting and plotting
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Visualize the results
plt.figure(figsize=(10, 6))
sns.barplot(data=importance_df, x='Importance', y='Feature', palette='mako')
plt.title('CatBoost Feature Importance')
plt.xlabel('Importance Score')
plt.ylabel('Features')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_23229/475268667.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=importance_df, x='Importance', y='Feature', palette='mako')
