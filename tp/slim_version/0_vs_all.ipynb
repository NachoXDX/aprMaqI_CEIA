# %% [markdown]
# # Binary Classification: Zero vs. Any Damage
# This model is the first tier of the hierarchical approach. Its goal is to maximize the recall for damage events while keeping a high precision for zero-damage cases.

# %%
import pandas as pd
import numpy as np
import optuna
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score, classification_report, f1_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# ---------------------------------------------------------
# 1. Load the Datasets & Transform to Binary
# ---------------------------------------------------------
print("Loading datasets...")

DATA_PATH = '../processed_datasets/'
X_TRAIN_PATH = DATA_PATH + 'X_train_catboost.parquet'
X_VAL_PATH = DATA_PATH + 'X_val_catboost.parquet'
X_TEST_PATH = DATA_PATH + 'X_test_catboost.parquet'

Y_TRAIN_PATH = DATA_PATH + 'y_train.csv'
Y_VAL_PATH = DATA_PATH + 'y_val.csv'
Y_TEST_PATH = DATA_PATH + 'y_test.csv'

X_train = pd.read_parquet(X_TRAIN_PATH, engine="fastparquet")
X_val = pd.read_parquet(X_VAL_PATH, engine="fastparquet")
X_test = pd.read_parquet(X_TEST_PATH, engine="fastparquet")

y_train_raw = pd.read_csv(Y_TRAIN_PATH).squeeze()
y_val_raw = pd.read_csv(Y_VAL_PATH).squeeze()
y_test_raw = pd.read_csv(Y_TEST_PATH).squeeze()

# TRANSFORM TO BINARY: 0 = No Damage, 1 = Any Damage (1-4)
y_train = (y_train_raw > 0).astype(int)
y_val = (y_val_raw > 0).astype(int)
y_test = (y_test_raw > 0).astype(int)

print(f"Target distribution (Train):\n{y_train.value_counts(normalize=True)}")
print(f"Train shapes: X={X_train.shape}, y={y_train.shape}")

categorical_features = X_train.select_dtypes(include=['object', 'category', 'string']).columns.tolist()
categorical_features.extend(['DAY_OF_WEEK'])
print(f"Detected {len(categorical_features)} categorical features.")
# Out:
# Loading datasets...
# Target distribution (Train):
# DAMAGE_CLASS
# 0    0.615161
# 1    0.384839
# Name: proportion, dtype: float64
# Train shapes: X=(876565, 32), y=(876565,)
# Detected 11 categorical features.

# %%
# ---------------------------------------------------------
# 2. Define the Optuna Objective Function
# ---------------------------------------------------------
def objective(trial):
    params = {
        "iterations": 2000,
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.1, log=True),
        "depth": trial.suggest_int("depth", 4, 10),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1, 10),
        "random_strength": trial.suggest_float("random_strength", 1, 10),
        "bagging_temperature": trial.suggest_float("bagging_temperature", 0, 1),
        "grow_policy": trial.suggest_categorical("grow_policy", ["SymmetricTree", "Depthwise", "Lossguide"]),
        "auto_class_weights": "Balanced",
        "random_seed": 42,
        "verbose": False,
        "task_type": "GPU",
        "eval_metric": "Logloss"
    }
    
    model = CatBoostClassifier(**params)

    model.fit(
        X_train, 
        y_train,
        cat_features=categorical_features,
        eval_set=[(X_val, y_val)],
        early_stopping_rounds=100, 
        use_best_model=True
    )

    preds_class = np.squeeze(model.predict(X_val))
    # We optimize for Macro F1 to ensure both classes are weighted equally in the gatekeeper model
    score = f1_score(y_val, preds_class, average='macro')
    
    return score

# %%
# ---------------------------------------------------------
# 3. Run the Optuna Study
# ---------------------------------------------------------
print("Starting Optuna hyperparameter tuning for Binary Gatekeeper...")

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=30)

print("\n--- Optimization Finished ---")
print(f"Best Macro F1: {study.best_value:.4f}")
print("Best Parameters:")
for key, value in study.best_params.items():
    print(f"  {key}: {value}")
# Out:
# [I 2026-06-09 18:18:21,846] A new study created in memory with name: no-name-7bf0c2c8-bcdc-4a70-b085-9f638f3810f8
# Starting Optuna hyperparameter tuning for Binary Gatekeeper...
# [I 2026-06-09 18:28:20,592] Trial 0 finished with value: 0.861363033165336 and parameters: {'learning_rate': 0.012163529473993196, 'depth': 6, 'l2_leaf_reg': 9.613521148945718, 'random_strength': 6.436127245298395, 'bagging_temperature': 0.811206619573193, 'grow_policy': 'SymmetricTree'}. Best is trial 0 with value: 0.861363033165336.
# [I 2026-06-09 18:29:48,948] Trial 1 finished with value: 0.8651641191828302 and parameters: {'learning_rate': 0.020232891682549298, 'depth': 10, 'l2_leaf_reg': 9.384880671746483, 'random_strength': 1.9773691001221039, 'bagging_temperature': 0.48620238333852195, 'grow_policy': 'Lossguide'}. Best is trial 1 with value: 0.8651641191828302.
# [I 2026-06-09 18:31:02,726] Trial 2 finished with value: 0.85241067162742 and parameters: {'learning_rate': 0.04216119487829322, 'depth': 4, 'l2_leaf_reg': 3.6078739610136434, 'random_strength': 8.545800502316645, 'bagging_temperature': 0.44159982732368475, 'grow_policy': 'Depthwise'}. Best is trial 1 with value: 0.8651641191828302.
# [I 2026-06-09 18:32:39,857] Trial 3 finished with value: 0.8531468154190427 and parameters: {'learning_rate': 0.004235480191559005, 'depth': 10, 'l2_leaf_reg': 4.743628037792631, 'random_strength': 2.4693567621028865, 'bagging_temperature': 0.4463582103586462, 'grow_policy': 'Lossguide'}. Best is trial 1 with value: 0.8651641191828302.
# [I 2026-06-09 18:33:30,348] Trial 4 finished with value: 0.8687195858646308 and parameters: {'learning_rate': 0.0128755046183959, 'depth': 9, 'l2_leaf_reg': 9.915863053218203, 'random_strength': 3.7445828252850037, 'bagging_temperature': 0.778107192685554, 'grow_policy': 'Depthwise'}. Best is trial 4 with value: 0.8687195858646308.
# [I 2026-06-09 18:34:36,122] Trial 5 finished with value: 0.810704165880805 and parameters: {'learning_rate': 0.0018665680319007783, 'depth': 4, 'l2_leaf_reg': 6.89616517734099, 'random_strength': 9.46695310641738, 'bagging_temperature': 0.5521004455579143, 'grow_policy': 'Depthwise'}. Best is trial 4 with value: 0.8687195858646308.
# [I 2026-06-09 18:38:48,764] Trial 6 finished with value: 0.8602001325735773 and parameters: {'learning_rate': 0.022451520146393622, 'depth': 10, 'l2_leaf_reg': 8.796565415572836, 'random_strength': 9.128278126551375, 'bagging_temperature': 0.983947593288365, 'grow_policy': 'SymmetricTree'}. Best is trial 4 with value: 0.8687195858646308.
# [I 2026-06-09 18:40:58,360] Trial 7 finished with value: 0.8694349602252793 and parameters: {'learning_rate': 0.003981613161498982, 'depth': 10, 'l2_leaf_reg': 1.2746480596133514, 'random_strength': 4.142052601020188, 'bagging_temperature': 0.4128192541975536, 'grow_policy': 'Depthwise'}. Best is trial 7 with value: 0.8694349602252793.
# [I 2026-06-09 18:42:01,022] Trial 8 finished with value: 0.8497687312443996 and parameters: {'learning_rate': 0.025948261503075727, 'depth': 4, 'l2_leaf_reg': 9.11813184862914, 'random_strength': 5.055798721901319, 'bagging_temperature': 0.5560875645253262, 'grow_policy': 'Lossguide'}. Best is trial 7 with value: 0.8694349602252793.
# [I 2026-06-09 18:43:05,683] Trial 9 finished with value: 0.8253795940532838 and parameters: {'learning_rate': 0.00359699329794244, 'depth': 4, 'l2_leaf_reg': 3.3235316026368005, 'random_strength': 5.918239576379025, 'bagging_temperature': 0.2749957751849823, 'grow_policy': 'Depthwise'}. Best is trial 7 with value: 0.8694349602252793.
# [I 2026-06-09 18:43:29,324] Trial 10 finished with value: 0.8639092602926525 and parameters: {'learning_rate': 0.09530232751216049, 'depth': 7, 'l2_leaf_reg': 1.0259270030863317, 'random_strength': 1.1275376854344445, 'bagging_temperature': 0.06978810874292563, 'grow_policy': 'Depthwise'}. Best is trial 7 with value: 0.8694349602252793.
# [I 2026-06-09 18:45:30,011] Trial 11 finished with value: 0.8662697695303533 and parameters: {'learning_rate': 0.005741308512835838, 'depth': 8, 'l2_leaf_reg': 1.0707779567319706, 'random_strength': 3.8181428738516696, 'bagging_temperature': 0.7622585869833578, 'grow_policy': 'Depthwise'}. Best is trial 7 with value: 0.8694349602252793.
# [I 2026-06-09 18:48:52,171] Trial 12 finished with value: 0.8610426429610276 and parameters: {'learning_rate': 0.0011740486196074058, 'depth': 9, 'l2_leaf_reg': 7.141412209680253, 'random_strength': 4.0501488777222265, 'bagging_temperature': 0.7293105028918158, 'grow_policy': 'Depthwise'}. Best is trial 7 with value: 0.8694349602252793.
# [I 2026-06-09 18:51:10,054] Trial 13 finished with value: 0.866912202806645 and parameters: {'learning_rate': 0.007885894140278809, 'depth': 8, 'l2_leaf_reg': 6.50369399994074, 'random_strength': 7.324917258297154, 'bagging_temperature': 0.2961553013904297, 'grow_policy': 'Depthwise'}. Best is trial 7 with value: 0.8694349602252793.
# [I 2026-06-09 18:53:57,934] Trial 14 finished with value: 0.868531476446009 and parameters: {'learning_rate': 0.002649110575855292, 'depth': 9, 'l2_leaf_reg': 2.5647429557698014, 'random_strength': 3.786464525144886, 'bagging_temperature': 0.981019552053308, 'grow_policy': 'Depthwise'}. Best is trial 7 with value: 0.8694349602252793.
# [I 2026-06-09 19:01:01,428] Trial 15 finished with value: 0.861549500869295 and parameters: {'learning_rate': 0.01143865737670403, 'depth': 9, 'l2_leaf_reg': 5.49344358533236, 'random_strength': 4.850941537645703, 'bagging_temperature': 0.24723177977111746, 'grow_policy': 'SymmetricTree'}. Best is trial 7 with value: 0.8694349602252793.
# [I 2026-06-09 19:02:58,890] Trial 16 finished with value: 0.866978859384571 and parameters: {'learning_rate': 0.007691597551677867, 'depth': 8, 'l2_leaf_reg': 7.9927042298505, 'random_strength': 2.819681234453545, 'bagging_temperature': 0.6490852471268662, 'grow_policy': 'Depthwise'}. Best is trial 7 with value: 0.8694349602252793.
# [I 2026-06-09 19:04:23,985] Trial 17 finished with value: 0.8389386505463432 and parameters: {'learning_rate': 0.0018027023467531344, 'depth': 6, 'l2_leaf_reg': 4.723053876647248, 'random_strength': 7.22144027799406, 'bagging_temperature': 0.8543016810302532, 'grow_policy': 'Depthwise'}. Best is trial 7 with value: 0.8694349602252793.
# [I 2026-06-09 19:06:55,186] Trial 18 finished with value: 0.8624437569024053 and parameters: {'learning_rate': 0.04085085491391776, 'depth': 9, 'l2_leaf_reg': 2.0883659288146266, 'random_strength': 3.2274269487072744, 'bagging_temperature': 0.006800212246243831, 'grow_policy': 'SymmetricTree'}. Best is trial 7 with value: 0.8694349602252793.
# [I 2026-06-09 19:08:23,122] Trial 19 finished with value: 0.8601758354273054 and parameters: {'learning_rate': 0.013275656027995025, 'depth': 7, 'l2_leaf_reg': 7.7853231192736665, 'random_strength': 4.633381033867764, 'bagging_temperature': 0.6325037774096898, 'grow_policy': 'Lossguide'}. Best is trial 7 with value: 0.8694349602252793.
# [I 2026-06-09 19:10:11,663] Trial 20 finished with value: 0.8687471067180667 and parameters: {'learning_rate': 0.00513154413888817, 'depth': 10, 'l2_leaf_reg': 5.855066270954842, 'random_strength': 1.517980446083833, 'bagging_temperature': 0.12740656539467327, 'grow_policy': 'Depthwise'}. Best is trial 7 with value: 0.8694349602252793.
# [I 2026-06-09 19:12:01,840] Trial 21 finished with value: 0.8687048671695905 and parameters: {'learning_rate': 0.005097990385899907, 'depth': 10, 'l2_leaf_reg': 5.697664626760231, 'random_strength': 1.2313550144516527, 'bagging_temperature': 0.14943810232263566, 'grow_policy': 'Depthwise'}. Best is trial 7 with value: 0.8694349602252793.
# [I 2026-06-09 19:15:44,940] Trial 22 finished with value: 0.8695803012845447 and parameters: {'learning_rate': 0.0026065724304786086, 'depth': 10, 'l2_leaf_reg': 4.0907346582444974, 'random_strength': 2.0573498869945923, 'bagging_temperature': 0.36388998800275657, 'grow_policy': 'Depthwise'}. Best is trial 22 with value: 0.8695803012845447.
# [I 2026-06-09 19:19:33,131] Trial 23 finished with value: 0.8687612986644193 and parameters: {'learning_rate': 0.002184674917544423, 'depth': 10, 'l2_leaf_reg': 4.200324270585832, 'random_strength': 1.894591522396931, 'bagging_temperature': 0.35611268404425617, 'grow_policy': 'Depthwise'}. Best is trial 22 with value: 0.8695803012845447.
# [I 2026-06-09 19:23:46,114] Trial 24 finished with value: 0.8645203709770698 and parameters: {'learning_rate': 0.0010435089704850247, 'depth': 10, 'l2_leaf_reg': 3.7921486325466924, 'random_strength': 2.2748700365976107, 'bagging_temperature': 0.3751072521939371, 'grow_policy': 'Depthwise'}. Best is trial 22 with value: 0.8695803012845447.
# [I 2026-06-09 19:25:53,782] Trial 25 finished with value: 0.8649264440423912 and parameters: {'learning_rate': 0.0024903736335572845, 'depth': 8, 'l2_leaf_reg': 2.638890777001973, 'random_strength': 3.1354078784719346, 'bagging_temperature': 0.3473393846034619, 'grow_policy': 'Depthwise'}. Best is trial 22 with value: 0.8695803012845447.
# [I 2026-06-09 19:28:41,865] Trial 26 finished with value: 0.8678610081082703 and parameters: {'learning_rate': 0.00283696538144485, 'depth': 9, 'l2_leaf_reg': 4.442333820333939, 'random_strength': 1.6904506791750618, 'bagging_temperature': 0.18908729340985753, 'grow_policy': 'Depthwise'}. Best is trial 22 with value: 0.8695803012845447.
# [I 2026-06-09 19:32:45,207] Trial 27 finished with value: 0.8683055707113309 and parameters: {'learning_rate': 0.0016410187758349795, 'depth': 10, 'l2_leaf_reg': 1.8592499507417326, 'random_strength': 2.5627876694017666, 'bagging_temperature': 0.3802083653647005, 'grow_policy': 'Depthwise'}. Best is trial 22 with value: 0.8695803012845447.
# [I 2026-06-09 19:39:54,493] Trial 28 finished with value: 0.8487450510784944 and parameters: {'learning_rate': 0.003304931497269144, 'depth': 5, 'l2_leaf_reg': 4.114069902389761, 'random_strength': 1.9635645227444802, 'bagging_temperature': 0.2297959010301053, 'grow_policy': 'SymmetricTree'}. Best is trial 22 with value: 0.8695803012845447.
# [I 2026-06-09 19:41:16,526] Trial 29 finished with value: 0.8250870971732074 and parameters: {'learning_rate': 0.001505935198959037, 'depth': 6, 'l2_leaf_reg': 2.7763491768189086, 'random_strength': 5.673039986053858, 'bagging_temperature': 0.33093041173229043, 'grow_policy': 'Lossguide'}. Best is trial 22 with value: 0.8695803012845447.
# --- Optimization Finished ---
# Best Macro F1: 0.8696
# Best Parameters:
#   learning_rate: 0.0026065724304786086
#   depth: 10
#   l2_leaf_reg: 4.0907346582444974
#   random_strength: 2.0573498869945923
#   bagging_temperature: 0.36388998800275657
#   grow_policy: Depthwise

# %%
# ---------------------------------------------------------
# 4. Train Final Model & Evaluate on Test Set
# ---------------------------------------------------------
print("\nTraining final binary model...")

final_params = study.best_params.copy()
final_params.update({
    "iterations": 2000,
    "auto_class_weights": "Balanced",
    "random_seed": 42,
    "verbose": False,
    "task_type": "GPU"
})

final_model = CatBoostClassifier(**final_params)

final_model.fit(
    X_train, 
    y_train,
    cat_features=categorical_features,
    eval_set=[(X_val, y_val)],
    early_stopping_rounds=100,
    use_best_model=True
)

y_pred = final_model.predict(X_test)
print(f"Final Test Accuracy: {accuracy_score(y_test, y_pred):.4f}\n")
print("Classification Report:")
print(classification_report(y_test, y_pred))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Training final binary model...
# Final Test Accuracy: 0.8842
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92     86950
#            1       0.76      0.78      0.77     29048
#
#     accuracy                           0.88    115998
#    macro avg       0.84      0.85      0.85    115998
# weighted avg       0.89      0.88      0.88    115998
#
# Confusion Matrix:
# [[79788  7162]
#  [ 6269 22779]]

# %%
final_model.save_model("catboost_binary.cbm")

# %% [markdown]
# ### Feature Importance

# %%
model = CatBoostClassifier().load_model("catboost_binary.cbm")

# %%
importances = model.get_feature_importance()
feature_names = model.feature_names_

# Pack them into a DataFrame for clean sorting and plotting
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Visualize the results
plt.figure(figsize=(10, 6))
sns.barplot(data=importance_df, x='Importance', y='Feature', palette='mako')
plt.title('CatBoost Feature Importance')
plt.xlabel('Importance Score')
plt.ylabel('Features')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_8075/475268667.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=importance_df, x='Importance', y='Feature', palette='mako')
