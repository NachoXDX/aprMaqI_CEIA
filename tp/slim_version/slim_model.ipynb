# %%
import pandas as pd
import numpy as np
import optuna
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score, classification_report, f1_score
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Carga

# %%
# ---------------------------------------------------------
# 1. Load the Datasets
# ---------------------------------------------------------
print("Loading datasets...")

DATA_PATH = '../processed_datasets/'
X_TRAIN_PATH = DATA_PATH + 'X_train_catboost.parquet'
X_VAL_PATH = DATA_PATH + 'X_val_catboost.parquet'
X_TEST_PATH = DATA_PATH + 'X_test_catboost.parquet'

Y_TRAIN_PATH = DATA_PATH + 'y_train.csv'
Y_VAL_PATH = DATA_PATH + 'y_val.csv'
Y_TEST_PATH = DATA_PATH + 'y_test.csv'
# Using fastparquet to avoid any ArrowKeyError version conflicts

features_to_drop = ['WFO', 'SOURCE']

# Load the data and drop the columns in one go
X_train = pd.read_parquet(X_TRAIN_PATH, engine="fastparquet").drop(columns=features_to_drop)
X_val = pd.read_parquet(X_VAL_PATH, engine="fastparquet").drop(columns=features_to_drop)
X_test = pd.read_parquet(X_TEST_PATH, engine="fastparquet").drop(columns=features_to_drop)

y_train = pd.read_csv(Y_TRAIN_PATH).squeeze()
y_val = pd.read_csv(Y_VAL_PATH).squeeze()
y_test = pd.read_csv(Y_TEST_PATH).squeeze()

print(f"Train shapes: X={X_train.shape}, y={y_train.shape}")
print(f"Validation shapes: X={X_val.shape}, y={y_val.shape}")
print(f"Test shapes: X={X_test.shape}, y={y_test.shape}\n")

categorical_features = X_train.select_dtypes(include=['object', 'category', 'string']).columns.tolist()
#Added day of week since its encoded but not ordinal
categorical_features.extend(['DAY_OF_WEEK'])
print(f"Detected {len(categorical_features)} categorical features: {categorical_features}")
# Out:
# Loading datasets...
# Train shapes: X=(876565, 30), y=(876565,)
# Validation shapes: X=(156915, 30), y=(156915,)
# Test shapes: X=(115998, 30), y=(115998,)
#
# Detected 9 categorical features: ['EVENT_TYPE', 'CZ_TYPE', 'STATE', 'REGION', 'SEASON', 'TIME_OF_DAY', 'MAGNITUDE_TYPE', 'FLOOD_CAUSE', 'DAY_OF_WEEK']

# %% [markdown]
# ### Optuna

# %%
# ---------------------------------------------------------
# 2. Define the Optuna Objective Function
# ---------------------------------------------------------
static_params = {
    "random_seed": 42,
    "verbose": False,
    "task_type": "GPU",
    "auto_class_weights": "Balanced",
    "eval_metric": "TotalF1:average=Macro"
}

def objective(trial):
    # Define the hyperparameter search space
    params = {
        "iterations": trial.suggest_int("iterations", 500, 2000),
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.1, log=True),
        "depth": trial.suggest_int("depth", 4, 10),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1, 10),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 1, 50),
    }
    params.update(static_params)
    # Instantiate the model for this trial
    model = CatBoostClassifier(**params)

    # Fit the model using the Validation set for early stopping
    model.fit(
        X_train, 
        y_train,
        cat_features=categorical_features,
        eval_set=[(X_val, y_val)],
        early_stopping_rounds=100, 
        use_best_model=True
    )

    # Predict discrete classes, not probabilities
    preds_class = model.predict(X_val)
    preds_class = np.squeeze(preds_class) # Ensure flat 1D array
    
    # Calculate Macro F1
    macro_f1 = f1_score(y_val, preds_class, average='macro')
    
    return macro_f1

# %%
# ---------------------------------------------------------
# 3. Run the Optuna Study
# ---------------------------------------------------------
print("Starting Optuna hyperparameter tuning...")

# Suppress Optuna's verbose trial-by-trial logs if desired
# optuna.logging.set_verbosity(optuna.logging.WARNING)

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=30) # Adjust n_trials based on your time constraints

print("\n--- Optimization Finished ---")
print(f"Best Validation Logloss: {study.best_value:.4f}")
print("Best Parameters:")
for key, value in study.best_params.items():
    print(f"  {key}: {value}")
# Out:
# [I 2026-06-10 08:39:39,976] A new study created in memory with name: no-name-28d1bd43-7cdd-411f-9464-1a8233649f7a
# Starting Optuna hyperparameter tuning...
# [I 2026-06-10 08:39:56,877] Trial 0 finished with value: 0.3767328509660347 and parameters: {'iterations': 1126, 'learning_rate': 0.0013708233239651763, 'depth': 8, 'l2_leaf_reg': 1.3552013828873015, 'min_data_in_leaf': 40}. Best is trial 0 with value: 0.3767328509660347.
# [I 2026-06-10 08:40:34,484] Trial 1 finished with value: 0.42322519145354487 and parameters: {'iterations': 931, 'learning_rate': 0.023872358956460917, 'depth': 4, 'l2_leaf_reg': 1.6360986258377794, 'min_data_in_leaf': 1}. Best is trial 1 with value: 0.42322519145354487.
# [I 2026-06-10 08:41:18,741] Trial 2 finished with value: 0.4253778200548747 and parameters: {'iterations': 1233, 'learning_rate': 0.024633994497099666, 'depth': 4, 'l2_leaf_reg': 6.6847163608870455, 'min_data_in_leaf': 20}. Best is trial 2 with value: 0.4253778200548747.
# [I 2026-06-10 08:42:24,462] Trial 3 finished with value: 0.44092395681030705 and parameters: {'iterations': 1729, 'learning_rate': 0.02492125495501259, 'depth': 9, 'l2_leaf_reg': 2.8963373699974424, 'min_data_in_leaf': 43}. Best is trial 3 with value: 0.44092395681030705.
# [I 2026-06-10 08:42:41,646] Trial 4 finished with value: 0.4270966935239505 and parameters: {'iterations': 541, 'learning_rate': 0.08845759621399735, 'depth': 4, 'l2_leaf_reg': 7.776959568451674, 'min_data_in_leaf': 44}. Best is trial 3 with value: 0.44092395681030705.
# [I 2026-06-10 08:43:08,655] Trial 5 finished with value: 0.37197857932619627 and parameters: {'iterations': 1565, 'learning_rate': 0.005171425893147855, 'depth': 4, 'l2_leaf_reg': 4.576887548603796, 'min_data_in_leaf': 21}. Best is trial 3 with value: 0.44092395681030705.
# [I 2026-06-10 08:44:18,320] Trial 6 finished with value: 0.43906491039805867 and parameters: {'iterations': 1506, 'learning_rate': 0.02863346248818944, 'depth': 7, 'l2_leaf_reg': 7.7828439421785, 'min_data_in_leaf': 30}. Best is trial 3 with value: 0.44092395681030705.
# [I 2026-06-10 08:45:01,964] Trial 7 finished with value: 0.3796047074866761 and parameters: {'iterations': 1488, 'learning_rate': 0.0021691523068085266, 'depth': 5, 'l2_leaf_reg': 8.597108712713052, 'min_data_in_leaf': 49}. Best is trial 3 with value: 0.44092395681030705.
# [I 2026-06-10 08:45:47,230] Trial 8 finished with value: 0.4068336211113655 and parameters: {'iterations': 1180, 'learning_rate': 0.007487730893911408, 'depth': 4, 'l2_leaf_reg': 6.42167575257803, 'min_data_in_leaf': 15}. Best is trial 3 with value: 0.44092395681030705.
# [I 2026-06-10 08:46:00,754] Trial 9 finished with value: 0.3765824917817074 and parameters: {'iterations': 1669, 'learning_rate': 0.001918895974592113, 'depth': 8, 'l2_leaf_reg': 1.2944372772407045, 'min_data_in_leaf': 38}. Best is trial 3 with value: 0.44092395681030705.
# [I 2026-06-10 08:46:30,603] Trial 10 finished with value: 0.43977753641036677 and parameters: {'iterations': 1957, 'learning_rate': 0.08584322265605676, 'depth': 10, 'l2_leaf_reg': 3.77333928450022, 'min_data_in_leaf': 32}. Best is trial 3 with value: 0.44092395681030705.
# [I 2026-06-10 08:47:04,953] Trial 11 finished with value: 0.4476252551346388 and parameters: {'iterations': 1998, 'learning_rate': 0.09290910257154575, 'depth': 10, 'l2_leaf_reg': 3.80374395197225, 'min_data_in_leaf': 32}. Best is trial 11 with value: 0.4476252551346388.
# [I 2026-06-10 08:47:50,761] Trial 12 finished with value: 0.4421875200489861 and parameters: {'iterations': 1975, 'learning_rate': 0.041425046661019434, 'depth': 10, 'l2_leaf_reg': 3.30484923375003, 'min_data_in_leaf': 35}. Best is trial 11 with value: 0.4476252551346388.
# [I 2026-06-10 08:48:31,189] Trial 13 finished with value: 0.43925164949291406 and parameters: {'iterations': 1974, 'learning_rate': 0.044991307768272676, 'depth': 10, 'l2_leaf_reg': 4.846198340021989, 'min_data_in_leaf': 33}. Best is trial 11 with value: 0.4476252551346388.
# [I 2026-06-10 08:49:04,513] Trial 14 finished with value: 0.44070661259313637 and parameters: {'iterations': 1845, 'learning_rate': 0.051063103324644504, 'depth': 9, 'l2_leaf_reg': 3.09623508065977, 'min_data_in_leaf': 26}. Best is trial 11 with value: 0.4476252551346388.
# [I 2026-06-10 08:50:20,112] Trial 15 finished with value: 0.4353577294739515 and parameters: {'iterations': 1791, 'learning_rate': 0.013802722099358478, 'depth': 10, 'l2_leaf_reg': 2.779169554491217, 'min_data_in_leaf': 9}. Best is trial 11 with value: 0.4476252551346388.
# [I 2026-06-10 08:50:53,041] Trial 16 finished with value: 0.43859122435131753 and parameters: {'iterations': 852, 'learning_rate': 0.05471435179374182, 'depth': 9, 'l2_leaf_reg': 5.800942563478704, 'min_data_in_leaf': 35}. Best is trial 11 with value: 0.4476252551346388.
# [I 2026-06-10 08:51:23,775] Trial 17 finished with value: 0.44109484694804485 and parameters: {'iterations': 1374, 'learning_rate': 0.09804422897088112, 'depth': 6, 'l2_leaf_reg': 4.165722566616462, 'min_data_in_leaf': 26}. Best is trial 11 with value: 0.4476252551346388.
# [I 2026-06-10 08:52:11,018] Trial 18 finished with value: 0.426504279469152 and parameters: {'iterations': 1993, 'learning_rate': 0.012315906399329479, 'depth': 8, 'l2_leaf_reg': 2.315975696816028, 'min_data_in_leaf': 48}. Best is trial 11 with value: 0.4476252551346388.
# [I 2026-06-10 08:53:12,223] Trial 19 finished with value: 0.4431142427585405 and parameters: {'iterations': 1641, 'learning_rate': 0.040727972450320435, 'depth': 7, 'l2_leaf_reg': 5.143865033751418, 'min_data_in_leaf': 21}. Best is trial 11 with value: 0.4476252551346388.
# [I 2026-06-10 08:53:47,279] Trial 20 finished with value: 0.39309364806551056 and parameters: {'iterations': 1636, 'learning_rate': 0.004700134023301943, 'depth': 6, 'l2_leaf_reg': 9.86491638624841, 'min_data_in_leaf': 13}. Best is trial 11 with value: 0.4476252551346388.
# [I 2026-06-10 08:54:22,168] Trial 21 finished with value: 0.43341353673186483 and parameters: {'iterations': 1831, 'learning_rate': 0.04041151150360529, 'depth': 7, 'l2_leaf_reg': 5.126412087968437, 'min_data_in_leaf': 20}. Best is trial 11 with value: 0.4476252551346388.
# [I 2026-06-10 08:54:46,938] Trial 22 finished with value: 0.4385524606451169 and parameters: {'iterations': 1870, 'learning_rate': 0.06221362222347559, 'depth': 9, 'l2_leaf_reg': 3.697671095976673, 'min_data_in_leaf': 28}. Best is trial 11 with value: 0.4476252551346388.
# [I 2026-06-10 08:55:58,745] Trial 23 finished with value: 0.4369559903629966 and parameters: {'iterations': 1405, 'learning_rate': 0.019211976016143523, 'depth': 10, 'l2_leaf_reg': 5.654106653953093, 'min_data_in_leaf': 37}. Best is trial 11 with value: 0.4476252551346388.
# [I 2026-06-10 08:57:04,640] Trial 24 finished with value: 0.43879642789982026 and parameters: {'iterations': 1757, 'learning_rate': 0.03829263981207468, 'depth': 6, 'l2_leaf_reg': 3.4271596720887305, 'min_data_in_leaf': 23}. Best is trial 11 with value: 0.4476252551346388.
# [I 2026-06-10 08:58:02,957] Trial 25 finished with value: 0.44801099790599236 and parameters: {'iterations': 1627, 'learning_rate': 0.06854323142107761, 'depth': 8, 'l2_leaf_reg': 2.0929481079191437, 'min_data_in_leaf': 31}. Best is trial 25 with value: 0.44801099790599236.
# [I 2026-06-10 08:58:53,569] Trial 26 finished with value: 0.4479654692609696 and parameters: {'iterations': 1395, 'learning_rate': 0.06868551669822182, 'depth': 7, 'l2_leaf_reg': 2.4909283580474164, 'min_data_in_leaf': 16}. Best is trial 25 with value: 0.44801099790599236.
# [I 2026-06-10 08:59:51,531] Trial 27 finished with value: 0.4411066281076656 and parameters: {'iterations': 1352, 'learning_rate': 0.06701023065939966, 'depth': 8, 'l2_leaf_reg': 1.9653626953648882, 'min_data_in_leaf': 15}. Best is trial 25 with value: 0.44801099790599236.
# [I 2026-06-10 09:01:05,071] Trial 28 finished with value: 0.4442822777843616 and parameters: {'iterations': 1056, 'learning_rate': 0.0732320730967025, 'depth': 7, 'l2_leaf_reg': 2.482829360523045, 'min_data_in_leaf': 7}. Best is trial 25 with value: 0.44801099790599236.
# [I 2026-06-10 09:01:34,586] Trial 29 finished with value: 0.4445302909870238 and parameters: {'iterations': 1092, 'learning_rate': 0.09677161814709646, 'depth': 8, 'l2_leaf_reg': 1.125737563276962, 'min_data_in_leaf': 30}. Best is trial 25 with value: 0.44801099790599236.
# --- Optimization Finished ---
# Best Validation Logloss: 0.4480
# Best Parameters:
#   iterations: 1627
#   learning_rate: 0.06854323142107761
#   depth: 8
#   l2_leaf_reg: 2.0929481079191437
#   min_data_in_leaf: 31

# %% [markdown]
# ### Entrenamiento

# %%
# ---------------------------------------------------------
# 4. Train Final Model & Evaluate on Test Set
# ---------------------------------------------------------
print("\nTraining final model with best parameters...")

# Initialize the final model

final_params = study.best_params.copy()
final_params.update(static_params)
final_model = CatBoostClassifier(**final_params)

# Retrain using Train set and use Validation set for early stopping one last time
final_model.fit(
    X_train, 
    y_train,
    cat_features=categorical_features,
    eval_set=[(X_val, y_val)],
    early_stopping_rounds=100,
    use_best_model=True
)
# Out:
# Training final model with best parameters...
# CatBoostClassifier(auto_class_weights='Balanced', depth=8, eval_metric='TotalF1:average=Macro', iterations=1627, l2_leaf_reg=2.0929481079191437, learning_rate=0.06854323142107761, min_data_in_leaf=31, random_seed=42, task_type='GPU', verbose=False)

# %% [markdown]
# ### Prediccion en Test

# %%
# Make final predictions on the completely unseen X_test
y_pred = final_model.predict(X_test)

# Print performance metrics
test_accuracy = accuracy_score(y_test, y_pred)
print(f"Final Test Accuracy: {test_accuracy:.4f}\n")

print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Final Test Accuracy: 0.7666
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88     86950
#            1       0.57      0.72      0.64     17859
#            2       0.24      0.29      0.26      7736
#            3       0.20      0.32      0.24      2274
#            4       0.19      0.51      0.28      1179
#
#     accuracy                           0.77    115998
#    macro avg       0.43      0.53      0.46    115998
# weighted avg       0.81      0.77      0.78    115998

# %%
final_model.save_model("catboost_slim.cbm")

# %% [markdown]
# ### Feature Importance

# %%
model = CatBoostClassifier().load_model("catboost_slim.cbm")

# %%
importances = model.get_feature_importance()
feature_names = model.feature_names_

# Pack them into a DataFrame for clean sorting and plotting
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Visualize the results
plt.figure(figsize=(10, 6))
sns.barplot(data=importance_df, x='Importance', y='Feature', palette='mako')
plt.title('CatBoost Feature Importance')
plt.xlabel('Importance Score')
plt.ylabel('Features')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_19748/475268667.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=importance_df, x='Importance', y='Feature', palette='mako')

# %%
import shap

# Initialize the tree explainer with your trained model
explainer = shap.TreeExplainer(model)

# Calculate SHAP values for your dataset
# For multiclass, this returns a list of arrays (one array per class)
shap_values = explainer.shap_values(X_train)

# Plot a summary plot for a comprehensive view
# This will stack the impact of features across your different classes
shap.summary_plot(shap_values, X_train, plot_type="bar")
