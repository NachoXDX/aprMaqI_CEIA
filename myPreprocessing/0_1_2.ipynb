# %%
import pandas as pd
import numpy as np
import optuna
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score, classification_report, f1_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# ---------------------------------------------------------
# 1. Load the Datasets & Transform to Binary
# ---------------------------------------------------------
print("Loading datasets...")

DATA_PATH = '../tp/processed_datasets/'
X_TRAIN_PATH = DATA_PATH + 'X_train_catboost.parquet'
X_VAL_PATH = DATA_PATH + 'X_val_catboost.parquet'
X_TEST_PATH = DATA_PATH + 'X_test_catboost.parquet'

Y_TRAIN_PATH = DATA_PATH + 'y_train.csv'
Y_VAL_PATH = DATA_PATH + 'y_val.csv'
Y_TEST_PATH = DATA_PATH + 'y_test.csv'

X_train = pd.read_parquet(X_TRAIN_PATH, engine="fastparquet")
X_val = pd.read_parquet(X_VAL_PATH, engine="fastparquet")
X_test = pd.read_parquet(X_TEST_PATH, engine="fastparquet")

y_train_raw = pd.read_csv(Y_TRAIN_PATH).squeeze()
y_val_raw = pd.read_csv(Y_VAL_PATH).squeeze()
y_test_raw = pd.read_csv(Y_TEST_PATH).squeeze()

# Transfrom (0,1,2,3,4) to (0,1,2)

y_train = np.clip(y_train_raw, 0, 2)
y_val   = np.clip(y_val_raw, 0, 2)
y_test  = np.clip(y_test_raw, 0, 2)

print(f"Target distribution (Train):\n{y_train.value_counts(normalize=True)}")
print(f"Train shapes: X={X_train.shape}, y={y_train.shape}")

categorical_features = X_train.select_dtypes(include=['object', 'category', 'string']).columns.tolist()
categorical_features.extend(['DAY_OF_WEEK'])
print(f"Detected {len(categorical_features)} categorical features.")
# Out:
# Loading datasets...
# Target distribution (Train):
# DAMAGE_CLASS
# 0    0.615161
# 2    0.215717
# 1    0.169122
# Name: proportion, dtype: float64
# Train shapes: X=(876565, 32), y=(876565,)
# Detected 11 categorical features.

# %%
# ---------------------------------------------------------
# 2. Define the Optuna Objective Function
# ---------------------------------------------------------
def objective(trial):
    params = {
        "iterations": 2000,
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.1, log=True),
        "depth": trial.suggest_int("depth", 4, 10),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1, 10),
        "random_strength": trial.suggest_float("random_strength", 1, 10),
        "bagging_temperature": trial.suggest_float("bagging_temperature", 0, 1),
        "grow_policy": trial.suggest_categorical("grow_policy", ["SymmetricTree", "Depthwise", "Lossguide"]),
        "auto_class_weights": "Balanced",
        "random_seed": 42,
        "verbose": False,
        "task_type": "GPU",
        "eval_metric": "TotalF1:average=Weighted"
    }
    
    model = CatBoostClassifier(**params)

    model.fit(
        X_train, 
        y_train,
        cat_features=categorical_features,
        eval_set=[(X_val, y_val)],
        early_stopping_rounds=100, 
        use_best_model=True
    )

    preds_class = np.squeeze(model.predict(X_val))
    # Optimizamos weighted f1 por el desbalance de clases
    score = f1_score(y_val, preds_class, average='weighted')
    
    return score

# %%
# ---------------------------------------------------------
# 3. Run the Optuna Study
# ---------------------------------------------------------
print("Starting Optuna hyperparameter...")

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=30)

print("\n--- Optimization Finished ---")
print(f"Best Weighted F1: {study.best_value:.4f}")
print("Best Parameters:")
for key, value in study.best_params.items():
    print(f"  {key}: {value}")
# Out:
# [I 2026-06-16 18:00:38,780] A new study created in memory with name: no-name-36501ff0-df9a-42f1-a72e-f5aa508a28c8
# Starting Optuna hyperparameter...
# [I 2026-06-16 18:01:08,003] Trial 0 finished with value: 0.8508552977483165 and parameters: {'learning_rate': 0.09908745923479702, 'depth': 7, 'l2_leaf_reg': 1.74443597284689, 'random_strength': 8.638265599780045, 'bagging_temperature': 0.5677941586415839, 'grow_policy': 'Lossguide'}. Best is trial 0 with value: 0.8508552977483165.
# [I 2026-06-16 18:02:42,051] Trial 1 finished with value: 0.8528870172521674 and parameters: {'learning_rate': 0.03431120034010267, 'depth': 10, 'l2_leaf_reg': 9.719031935032724, 'random_strength': 7.587874727550555, 'bagging_temperature': 0.023454523391706728, 'grow_policy': 'SymmetricTree'}. Best is trial 1 with value: 0.8528870172521674.
# [I 2026-06-16 18:03:23,245] Trial 2 finished with value: 0.8556859192253249 and parameters: {'learning_rate': 0.0318210864062996, 'depth': 10, 'l2_leaf_reg': 9.453598680393311, 'random_strength': 3.314289186483696, 'bagging_temperature': 0.15838842045510815, 'grow_policy': 'Depthwise'}. Best is trial 2 with value: 0.8556859192253249.
# [I 2026-06-16 18:03:38,078] Trial 3 finished with value: 0.7946292701450519 and parameters: {'learning_rate': 0.0030241117517206643, 'depth': 8, 'l2_leaf_reg': 6.326541220573624, 'random_strength': 2.730685877988069, 'bagging_temperature': 0.35096500539998954, 'grow_policy': 'Lossguide'}. Best is trial 2 with value: 0.8556859192253249.
# [I 2026-06-16 18:05:02,993] Trial 4 finished with value: 0.8394944048461302 and parameters: {'learning_rate': 0.008961036916971317, 'depth': 6, 'l2_leaf_reg': 5.094260950679307, 'random_strength': 1.079815798990424, 'bagging_temperature': 0.11055674291154072, 'grow_policy': 'Depthwise'}. Best is trial 2 with value: 0.8556859192253249.
# [I 2026-06-16 18:05:59,607] Trial 5 finished with value: 0.8521494544154814 and parameters: {'learning_rate': 0.056900057682280646, 'depth': 8, 'l2_leaf_reg': 9.614382255656686, 'random_strength': 9.102121197331552, 'bagging_temperature': 0.4357343509505708, 'grow_policy': 'SymmetricTree'}. Best is trial 2 with value: 0.8556859192253249.
# [I 2026-06-16 18:07:27,928] Trial 6 finished with value: 0.8513988957938247 and parameters: {'learning_rate': 0.007447759880635335, 'depth': 9, 'l2_leaf_reg': 6.403031607895725, 'random_strength': 9.09409047352129, 'bagging_temperature': 0.17706402205254224, 'grow_policy': 'Depthwise'}. Best is trial 2 with value: 0.8556859192253249.
# [I 2026-06-16 18:07:41,151] Trial 7 finished with value: 0.8094124415088704 and parameters: {'learning_rate': 0.003086560898123044, 'depth': 7, 'l2_leaf_reg': 1.2870366127566601, 'random_strength': 6.967803972728807, 'bagging_temperature': 0.8309755705647693, 'grow_policy': 'Depthwise'}. Best is trial 2 with value: 0.8556859192253249.
# [I 2026-06-16 18:08:21,343] Trial 8 finished with value: 0.8500522660128421 and parameters: {'learning_rate': 0.041145666329658326, 'depth': 9, 'l2_leaf_reg': 8.018680300364544, 'random_strength': 3.581563246062041, 'bagging_temperature': 0.27250200785088496, 'grow_policy': 'Lossguide'}. Best is trial 2 with value: 0.8556859192253249.
# [I 2026-06-16 18:08:44,854] Trial 9 finished with value: 0.7888419219743164 and parameters: {'learning_rate': 0.002505424216643475, 'depth': 4, 'l2_leaf_reg': 4.931101049028605, 'random_strength': 3.3764122596645754, 'bagging_temperature': 0.3245561681712982, 'grow_policy': 'Depthwise'}. Best is trial 2 with value: 0.8556859192253249.
# [I 2026-06-16 18:08:54,800] Trial 10 finished with value: 0.7927005103659307 and parameters: {'learning_rate': 0.0010174212767895421, 'depth': 5, 'l2_leaf_reg': 2.9272490161008693, 'random_strength': 5.4672285414448, 'bagging_temperature': 0.6721344083426553, 'grow_policy': 'Depthwise'}. Best is trial 2 with value: 0.8556859192253249.
# [I 2026-06-16 18:10:55,672] Trial 11 finished with value: 0.8518717804880858 and parameters: {'learning_rate': 0.021527867757030212, 'depth': 10, 'l2_leaf_reg': 9.799498094162248, 'random_strength': 5.844999911489107, 'bagging_temperature': 0.0031925456612446265, 'grow_policy': 'SymmetricTree'}. Best is trial 2 with value: 0.8556859192253249.
# [I 2026-06-16 18
 'grow_policy': 'Depthwise'}. Best is trial 2 with value: 0.8556859192253249.
# [I 2026-06-16 18:25:55,364] Trial 24 finished with value: 0.8531728064719796 and parameters: {'learning_rate': 0.056136128383021316, 'depth': 9, 'l2_leaf_reg': 6.181346475076785, 'random_strength': 1.970100767901239, 'bagging_temperature': 0.388727470599199, 'grow_policy': 'Depthwise'}. Best is trial 2 with value: 0.8556859192253249.
# [I 2026-06-16 18:26:49,714] Trial 25 finished with value: 0.8532909943107911 and parameters: {'learning_rate': 0.014910832325022634, 'depth': 10, 'l2_leaf_reg': 8.604670510091292, 'random_strength': 1.1851560635130884, 'bagging_temperature': 0.23699449595842426, 'grow_policy': 'Depthwise'}. Best is trial 2 with value: 0.8556859192253249.
# [I 2026-06-16 18:29:00,134] Trial 26 finished with value: 0.8520058263473929 and parameters: {'learning_rate': 0.0052302190722238835, 'depth': 9, 'l2_leaf_reg': 7.684322010415449, 'random_strength': 2.866027199512208, 'bagging_temperature': 0.5531104521322217, 'grow_policy': 'Depthwise'}. Best is trial 2 with value: 0.8556859192253249.
# [I 2026-06-16 18:29:35,038] Trial 27 finished with value: 0.8523634583053714 and parameters: {'learning_rate': 0.026185997738341835, 'depth': 10, 'l2_leaf_reg': 9.247979146322294, 'random_strength': 4.187000332410227, 'bagging_temperature': 0.3012082943214325, 'grow_policy': 'Depthwise'}. Best is trial 2 with value: 0.8556859192253249.
# [I 2026-06-16 18:29:54,150] Trial 28 finished with value: 0.8502499535101892 and parameters: {'learning_rate': 0.06947008303916959, 'depth': 8, 'l2_leaf_reg': 6.884246979507346, 'random_strength': 1.9800176385832655, 'bagging_temperature': 0.41758196151115246, 'grow_policy': 'Depthwise'}. Best is trial 2 with value: 0.8556859192253249.
# [I 2026-06-16 18:31:07,879] Trial 29 finished with value: 0.8408497755007881 and parameters: {'learning_rate': 0.010803042263846502, 'depth': 7, 'l2_leaf_reg': 8.500787675259986, 'random_strength': 3.10075681808248, 'bagging_temperature': 0.5988237248461642, 'grow_policy': 'Lossguide'}. Best is trial 2 with value: 0.8556859192253249.
# --- Optimization Finished ---
# Best Weighted F1: 0.8557
# Best Parameters:
#   learning_rate: 0.0318210864062996
#   depth: 10
#   l2_leaf_reg: 9.453598680393311
#   random_strength: 3.314289186483696
#   bagging_temperature: 0.15838842045510815
#   grow_policy: Depthwise

# %%
# ---------------------------------------------------------
# 4. Train Final Model & Evaluate on Test Set
# ---------------------------------------------------------
print("\nTraining final binary model...")

final_params = study.best_params.copy()
final_params.update({
    "iterations": 2000,
    "auto_class_weights": "Balanced",
    "random_seed": 42,
    "verbose": False,
    "task_type": "GPU"
})

final_model = CatBoostClassifier(**final_params)

final_model.fit(
    X_train, 
    y_train,
    cat_features=categorical_features,
    eval_set=[(X_val, y_val)],
    early_stopping_rounds=100,
    use_best_model=True
)

y_pred = final_model.predict(X_test)
print(f"Final Test Accuracy: {accuracy_score(y_test, y_pred):.4f}\n")
print("Classification Report:")
print(classification_report(y_test, y_pred))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Training final binary model...
# Final Test Accuracy: 0.8322
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.91     86950
#            1       0.62      0.76      0.68     17859
#            2       0.47      0.49      0.48     11189
#
#     accuracy                           0.83    115998
#    macro avg       0.68      0.71      0.69    115998
# weighted avg       0.85      0.83      0.84    115998
#
# Confusion Matrix:
# [[77528  5053  4369]
#  [ 2414 13501  1944]
#  [ 2586  3098  5505]]

# %%
final_model.save_model("catboost_012.cbm")

# %% [markdown]
# ### Feature Importance

# %%
model = CatBoostClassifier().load_model("catboost_012.cbm")

# %%
importances = model.get_feature_importance()
feature_names = model.feature_names_

# Pack them into a DataFrame for clean sorting and plotting
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Visualize the results
plt.figure(figsize=(10, 6))
sns.barplot(data=importance_df, x='Importance', y='Feature', palette='mako')
plt.title('CatBoost Feature Importance')
plt.xlabel('Importance Score')
plt.ylabel('Features')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_45524/475268667.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=importance_df, x='Importance', y='Feature', palette='mako')
