# %%
import pandas as pd
import numpy as np
import optuna
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score, classification_report, f1_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# ---------------------------------------------------------
# 1. Load the Datasets & Transform to Binary
# ---------------------------------------------------------
print("Loading datasets...")
cols_to_drop = ['WFO', 'SOURCE']
DATA_PATH = '../tp/processed_datasets/'
X_TRAIN_PATH = DATA_PATH + 'X_train_catboost.parquet'
X_VAL_PATH = DATA_PATH + 'X_val_catboost.parquet'
X_TEST_PATH = DATA_PATH + 'X_test_catboost.parquet'

Y_TRAIN_PATH = DATA_PATH + 'y_train.csv'
Y_VAL_PATH = DATA_PATH + 'y_val.csv'
Y_TEST_PATH = DATA_PATH + 'y_test.csv'

X_train = pd.read_parquet(X_TRAIN_PATH, engine="fastparquet").drop(columns=cols_to_drop)
X_val = pd.read_parquet(X_VAL_PATH, engine="fastparquet").drop(columns=cols_to_drop)
X_test = pd.read_parquet(X_TEST_PATH, engine="fastparquet").drop(columns=cols_to_drop)

y_train_raw = pd.read_csv(Y_TRAIN_PATH).squeeze()
y_val_raw = pd.read_csv(Y_VAL_PATH).squeeze()
y_test_raw = pd.read_csv(Y_TEST_PATH).squeeze()

# Transfrom (0,1,2,3,4) to (0,1,2)

y_train = np.clip(y_train_raw, 0, 2)
y_val   = np.clip(y_val_raw, 0, 2)
y_test  = np.clip(y_test_raw, 0, 2)

print(f"Target distribution (Train):\n{y_train.value_counts(normalize=True)}")
print(f"Train shapes: X={X_train.shape}, y={y_train.shape}")

categorical_features = X_train.select_dtypes(include=['object', 'category', 'string']).columns.tolist()
categorical_features.extend(['DAY_OF_WEEK'])
print(f"Detected {len(categorical_features)} categorical features.")
# Out:
# Loading datasets...
# Target distribution (Train):
# DAMAGE_CLASS
# 0    0.615161
# 2    0.215717
# 1    0.169122
# Name: proportion, dtype: float64
# Train shapes: X=(876565, 30), y=(876565,)
# Detected 9 categorical features.

# %%
# ---------------------------------------------------------
# 2. Define the Optuna Objective Function
# ---------------------------------------------------------
def objective(trial):
    params = {
        "iterations": 2000,
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.1, log=True),
        "depth": trial.suggest_int("depth", 4, 10),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1, 10),
        "random_strength": trial.suggest_float("random_strength", 1, 10),
        "bagging_temperature": trial.suggest_float("bagging_temperature", 0, 1),
        "grow_policy": trial.suggest_categorical("grow_policy", ["SymmetricTree", "Depthwise", "Lossguide"]),
        "auto_class_weights": "Balanced",
        "random_seed": 42,
        "verbose": False,
        "task_type": "GPU",
        "eval_metric": "TotalF1:average=Weighted"
    }
    
    model = CatBoostClassifier(**params)

    model.fit(
        X_train, 
        y_train,
        cat_features=categorical_features,
        eval_set=[(X_val, y_val)],
        early_stopping_rounds=100, 
        use_best_model=True
    )

    preds_class = np.squeeze(model.predict(X_val))
    # Optimizamos weighted f1 por el desbalance de clases
    score = f1_score(y_val, preds_class, average='weighted')
    
    return score

# %%
# ---------------------------------------------------------
# 3. Run the Optuna Study
# ---------------------------------------------------------
print("Starting Optuna hyperparameter...")

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=30)

print("\n--- Optimization Finished ---")
print(f"Best Weighted F1: {study.best_value:.4f}")
print("Best Parameters:")
for key, value in study.best_params.items():
    print(f"  {key}: {value}")
# Out:
# [I 2026-06-16 21:02:51,505] A new study created in memory with name: no-name-bf78b00f-7118-45fa-b73f-1e4246b56bf6
# Starting Optuna hyperparameter...
# [I 2026-06-16 21:04:34,396] Trial 0 finished with value: 0.8101439978137032 and parameters: {'learning_rate': 0.004308391786145114, 'depth': 8, 'l2_leaf_reg': 8.847963607081848, 'random_strength': 8.268178749366545, 'bagging_temperature': 0.004383075776090983, 'grow_policy': 'SymmetricTree'}. Best is trial 0 with value: 0.8101439978137032.
# [I 2026-06-16 21:05:10,668] Trial 1 finished with value: 0.8198928898574194 and parameters: {'learning_rate': 0.0817484661445824, 'depth': 4, 'l2_leaf_reg': 5.264493888126932, 'random_strength': 7.81178177880363, 'bagging_temperature': 0.3674920667592657, 'grow_policy': 'SymmetricTree'}. Best is trial 1 with value: 0.8198928898574194.
# [I 2026-06-16 21:05:20,204] Trial 2 finished with value: 0.7699573669705829 and parameters: {'learning_rate': 0.001959373526675258, 'depth': 7, 'l2_leaf_reg': 6.774312840378961, 'random_strength': 5.167487041475561, 'bagging_temperature': 0.9132774581426789, 'grow_policy': 'Depthwise'}. Best is trial 1 with value: 0.8198928898574194.
# [I 2026-06-16 21:06:37,768] Trial 3 finished with value: 0.8227185068234262 and parameters: {'learning_rate': 0.012406209384880804, 'depth': 5, 'l2_leaf_reg': 1.7615934321442492, 'random_strength': 7.121060108795714, 'bagging_temperature': 0.6365901839780141, 'grow_policy': 'Lossguide'}. Best is trial 3 with value: 0.8227185068234262.
# [I 2026-06-16 21:07:46,142] Trial 4 finished with value: 0.8400590234783072 and parameters: {'learning_rate': 0.052168130866369546, 'depth': 6, 'l2_leaf_reg': 4.892404521687307, 'random_strength': 6.384446551186168, 'bagging_temperature': 0.8459235614808156, 'grow_policy': 'Lossguide'}. Best is trial 4 with value: 0.8400590234783072.
# [I 2026-06-16 21:09:36,486] Trial 5 finished with value: 0.8403485914594856 and parameters: {'learning_rate': 0.030928561578988503, 'depth': 10, 'l2_leaf_reg': 9.923625610317472, 'random_strength': 6.208984803231391, 'bagging_temperature': 0.6139015812653107, 'grow_policy': 'SymmetricTree'}. Best is trial 5 with value: 0.8403485914594856.
# [I 2026-06-16 21:10:22,799] Trial 6 finished with value: 0.8053999839126588 and parameters: {'learning_rate': 0.005226817794972171, 'depth': 7, 'l2_leaf_reg': 3.449648906759579, 'random_strength': 5.396787082406744, 'bagging_temperature': 0.2998318576299045, 'grow_policy': 'Lossguide'}. Best is trial 5 with value: 0.8403485914594856.
# [I 2026-06-16 21:12:03,964] Trial 7 finished with value: 0.8213936704715548 and parameters: {'learning_rate': 0.003415929529497703, 'depth': 7, 'l2_leaf_reg': 6.106827941257254, 'random_strength': 4.954112038084468, 'bagging_temperature': 0.8086550066205175, 'grow_policy': 'Depthwise'}. Best is trial 5 with value: 0.8403485914594856.
# [I 2026-06-16 21:13:05,983] Trial 8 finished with value: 0.8386659219268918 and parameters: {'learning_rate': 0.06680949354769417, 'depth': 5, 'l2_leaf_reg': 7.767581981949902, 'random_strength': 7.031338336074337, 'bagging_temperature': 0.007779318375377375, 'grow_policy': 'Depthwise'}. Best is trial 5 with value: 0.8403485914594856.
# [I 2026-06-16 21:13:40,677] Trial 9 finished with value: 0.8044654982298329 and parameters: {'learning_rate': 0.006090099891129684, 'depth': 5, 'l2_leaf_reg': 6.641861548318327, 'random_strength': 3.004484762480995, 'bagging_temperature': 0.19941595747383845, 'grow_policy': 'Lossguide'}. Best is trial 5 with value: 0.8403485914594856.
# [I 2026-06-16 21:16:05,636] Trial 10 finished with value: 0.8391803303142578 and parameters: {'learning_rate': 0.020869196668814847, 'depth': 10, 'l2_leaf_reg': 9.928174430922034, 'random_strength': 9.706661212507091, 'bagging_temperature': 0.5923526418224448, 'grow_policy': 'SymmetricTree'}. Best is trial 5 with value: 0.8403485914594856.
# [I 2026-06-16 21:17:47,389] Trial 11 finished with value: 0.8392283569227801 and parameters: {'learning_rate': 0.03171156156635475, 'depth': 10, 'l2_leaf_reg': 4.10489250594556, 'random_strength': 3.4772205486003176, 'bagging_temperature': 0.760593881556467, 'grow_policy': 'SymmetricTree'}. Best is trial 5 with value: 0.8403485914594856.
# [I 2026-06-16 21:18:49,202] Trial 12 finished with value: 0.8411128380762638 and parameters: {'learning_rate': 0.03813686593703946, 'depth': 9, 'l2_leaf_reg': 4.456227174070251, 'random_strength': 1.1972183392571427, 'bagging_temperature': 0.9927933249698325, 'grow_policy': 'Lossguide'}. Best is trial 12 with value: 0.8411128380762638.
# [I 2026-06-16 21:19:56,196] Trial 13 finished with value: 0.8359850630021548 and parameters: {'learning_rate': 0.021585463327865324, 'depth': 9, 'l2_leaf_reg': 2.7094015240564233, 'random_strength': 1.7308530035954575, 'bagging_temperature': 0.9841564487335789, 'grow_policy': 'Lossguide'}. Best is trial 12 with value: 0.8411128380762638.
# [I 2026-06-16 21:21:14,287] Trial 14 finished with value: 0.8376325932183888 and parameters: {'learning_rate': 0.0341415481932121, 'depth': 9, 'l2_leaf_reg': 7.746698110640312, 'random_strength': 1.153299109176455, 'bagging_temperature': 0.4985984922212362, 'grow_policy': 'SymmetricTree'}. Best is trial 12 with value: 0.8411128380762638.
# [I 2026-06-16 21:22:27,056] Trial 15 finished with value: 0.8333780316175631 and parameters: {'learning_rate': 0.016082921027706105, 'depth': 9, 'l2_leaf_reg': 1.1381079907133103, 'random_strength': 3.3136921365179473, 'bagging_temperature': 0.6811607139205722, 'grow_policy': 'Lossguide'}. Best is trial 12 with value: 0.8411128380762638.
# [I 2026-06-16 21:23:42,080] Trial 16 finished with value: 0.8391960096323665 and parameters: {'learning_rate': 0.04220508205512669, 'depth': 10, 'l2_leaf_reg': 9.965925336881405, 'random_strength': 4.4963760136807505, 'bagging_temperature': 0.49370735836597257, 'grow_policy': 'SymmetricTree'}. Best is trial 12 with value: 0.8411128380762638.
# [I 2026-06-16 21:25:23,537] Trial 17 finished with value: 0.8224666847372624 and parameters: {'learning_rate': 0.008692680173857284, 'depth': 8, 'l2_leaf_reg': 3.45067992738573, 'random_strength': 2.365198706954711, 'bagging_temperature': 0.985645821744033, 'grow_policy': 'SymmetricTree'}. Best is trial 12 with value: 0.8411128380762638.
# [I 2026-06-16 21:26:32,640] Trial 18 finished with value: 0.838011745130539 and parameters: {'learning_rate': 0.027142361104372802, 'depth': 8, 'l2_leaf_reg': 4.416063977055693, 'random_strength': 4.216182567086661, 'bagging_temperature': 0.7216740960933102, 'grow_policy': 'Lossguide'}. Best is trial 12 with value: 0.8411128380762638.
# [I 2026-06-16 21:26:51,090] Trial 19 finished with value: 0.8393254878840162 and parameters: {'learning_rate': 0.09188410848735137, 'depth': 9, 'l2_leaf_reg': 7.816326081715572, 'random_strength': 6.1389862972488904, 'bagging_temperature': 0.3318611911983572, 'grow_policy': 'Depthwise'}. Best is trial 12 with value: 0.8411128380762638.
# [I 2026-06-16 21:26:59,739] Trial 20 finished with value: 0.7839478775908839 and parameters: {'learning_rate': 0.001308313882838648, 'depth': 10, 'l2_leaf_reg': 5.729889250590954, 'random_strength': 8.981304821248004, 'bagging_temperature': 0.5700752974435859, 'grow_policy': 'Lossguide'}. Best is trial 12 with value: 0.8411128380762638.
# [I 2026-06-16 21:27:45,188] Trial 21 finished with value: 0.8355427972738435 and parameters: {'learning_rate': 0.051378800097641994, 'depth': 6, 'l2_leaf_reg': 4.911785223131589, 'random_strength': 6.406711948505488, 'bagging_temperature': 0.8441481466526789, 'grow_policy': 'Lossguide'}. Best is trial 12 with value: 0.8411128380762638.
# [I 2026-06-16 21:28:43,733] Trial 22 finished with value: 0.8400698949406883 and parameters: {'learning_rate': 0.0562635838952748, 'depth': 6, 'l2_leaf_reg': 2.695360268934909, 'random_strength': 6.149969046446182, 'bagging_temperature': 0.8581397307997176, 'grow_policy': 'Lossguide'}. Best is trial 12 with value: 0.8411128380762638.
# [I 2026-06-16 21:29:52,215] Trial 23 finished with value: 0.8401744010544332 and parameters: {'learning_rate': 0.05518295504819234, 'depth': 6, 'l2_leaf_reg': 2.547644519566289, 'random_strength': 5.823787793352194, 'bagging_temperature': 0.904372786688995, 'grow_policy': 'Lossguide'}. Best is trial 12 with value: 0.8411128380762638.
# [I 2026-06-16 21:31:06,786] Trial 24 finished with value: 0.8309666338982838 and parameters: {'learning_rate': 0.014857375521071787, 'depth': 8, 'l2_leaf_reg': 2.424747189486349, 'random_strength': 4.37826308126669, 'bagging_temperature': 0.9163908303729464, 'grow_policy': 'Lossguide'}. Best is trial 12 with value: 0.8411128380762638.
# [I 2026-06-16 21:32:06,510] Trial 25 finished with value: 0.8347434558201442 and parameters: {'learning_rate': 0.03792631329587766, 'depth': 9, 'l2_leaf_reg': 3.6662919908284195, 'random_strength': 7.545487895649643, 'bagging_temperature': 0.9235777511915603, 'grow_policy': 'SymmetricTree'}. Best is trial 12 with value: 0.8411128380762638.
# [I 2026-06-16 21:33:02,168] Trial 26 finished with value: 0.818332494747819 and parameters: {'learning_rate': 0.021333430341962376, 'depth': 4, 'l2_leaf_reg': 1.980866620198491, 'random_strength': 5.706535476107992, 'bagging_temperature': 0.7859649439856589, 'grow_policy': 'Lossguide'}. Best is trial 12 with value: 0.8411128380762638.
# [I 2026-06-16 21:34:13,099] Trial 27 finished with value: 0.8251760470063564 and parameters: {'learning_rate': 0.008774774143806983, 'depth': 10, 'l2_leaf_reg': 8.731394048284471, 'random_strength': 8.567957109154886, 'bagging_temperature': 0.9931576802648748, 'grow_policy': 'Lossguide'}. Best is trial 12 with value: 0.8411128380762638.
# [I 2026-06-16 21:34:57,817] Trial 28 finished with value: 0.8433053525067538 and parameters: {'learning_rate': 0.09245324430742186, 'depth': 6, 'l2_leaf_reg': 1.323936492790084, 'random_strength': 3.910654753498687, 'bagging_temperature': 0.40772541619866687, 'grow_policy': 'Depthwise'}. Best is trial 28 with value: 0.8433053525067538.
# [I 2026-06-16 21:35:23,246] Trial 29 finished with value: 0.8430845939019944 and parameters: {'learning_rate': 0.09933442200918667, 'depth': 7, 'l2_leaf_reg': 1.2157121622737987, 'random_strength': 1.0446751392811775, 'bagging_temperature': 0.21564076084103875, 'grow_policy': 'Depthwise'}. Best is trial 28 with value: 0.8433053525067538.
# --- Optimization Finished ---
# Best Weighted F1: 0.8433
# Best Parameters:
#   learning_rate: 0.09245324430742186
#   depth: 6
#   l2_leaf_reg: 1.323936492790084
#   random_strength: 3.910654753498687
#   bagging_temperature: 0.40772541619866687
#   grow_policy: Depthwise

# %%
# ---------------------------------------------------------
# 4. Train Final Model & Evaluate on Test Set
# ---------------------------------------------------------
final_params = study.best_params.copy()
final_params.update({
    "iterations": 2000,
    "auto_class_weights": "Balanced",
    "random_seed": 42,
    "verbose": False,
    "task_type": "GPU"
})

final_model = CatBoostClassifier(**final_params)

final_model.fit(
    X_train, 
    y_train,
    cat_features=categorical_features,
    eval_set=[(X_val, y_val)],
    early_stopping_rounds=100,
    use_best_model=True
)

y_pred = final_model.predict(X_test)
print(f"Final Test Accuracy: {accuracy_score(y_test, y_pred):.4f}\n")
print("Classification Report:")
print(classification_report(y_test, y_pred))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Final Test Accuracy: 0.8167
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90     86950
#            1       0.60      0.76      0.67     17859
#            2       0.42      0.46      0.44     11189
#
#     accuracy                           0.82    115998
#    macro avg       0.65      0.70      0.67    115998
# weighted avg       0.83      0.82      0.82    115998
#
# Confusion Matrix:
# [[75975  5693  5282]
#  [ 2530 13586  1743]
#  [ 2829  3185  5175]]

# %%
final_model.save_model("catboost_012_drop.cbm")

# %% [markdown]
# ### Feature Importance

# %%
model = CatBoostClassifier().load_model("catboost_012_drop.cbm")

# %%
importances = model.get_feature_importance()
feature_names = model.feature_names_

# Pack them into a DataFrame for clean sorting and plotting
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Visualize the results
plt.figure(figsize=(10, 6))
sns.barplot(data=importance_df, x='Importance', y='Feature', palette='mako')
plt.title('CatBoost Feature Importance')
plt.xlabel('Importance Score')
plt.ylabel('Features')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_118902/475268667.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=importance_df, x='Importance', y='Feature', palette='mako')
